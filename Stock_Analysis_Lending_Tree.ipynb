# %%
import datetime
startDate = datetime.datetime(2008,1,1)
endDate = datetime.datetime(2018,10,7)

# %%
import pandas_datareader as pdr
stock = pdr.get_data_yahoo("TREE", startDate, endDate)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-949e101acb37> in <module>()
#       1 import pandas_datareader as pdr
# ----> 2 stock = pdr.get_data_yahoo("TREE", startDate, endDate)
#
# NameError: name 'startDate' is not defined

# %%
print(stock)
# Out:
#                   High         Low        Open       Close    Volume  \
# Date
# 2008-08-12    8.000000    6.500000    8.000000    7.320000   11300.0
# 2008-08-13    9.010000    7.810000    7.830000    8.650000   16000.0
# 2008-08-14   10.180000    8.600000    8.600000   10.090000   29600.0
# 2008-08-15   11.100000    9.800000   10.100000    9.810000   30500.0
# 2008-08-18    9.900000    8.100000    9.900000    8.340000   37300.0
# 2008-08-19    8.100000    7.100000    8.050000    7.650000  101700.0
# 2008-08-20    7.750000    7.060000    7.550000    7.420000  341400.0
# 2008-08-21    9.000000    6.980000    7.000000    7.460000  675400.0
# 2008-08-22    8.280000    7.500000    7.500000    7.990000  271400.0
# 2008-08-25    8.890000    8.050000    8.530000    8.190000  230000.0
# 2008-08-26    8.140000    7.360000    8.050000    7.720000  118900.0
# 2008-08-27    7.950000    7.190000    7.510000    7.600000  137800.0
# ...

# %%
df_stock=stock.pct_change()["Adj Close"]

# %%
print(stock["Adj Close"])
# Out:
# Date
# 2008-08-12      6.899311
# 2008-08-13      8.152873
# 2008-08-14      9.510115
# 2008-08-15      9.246207
# 2008-08-18      7.860690
# 2008-08-19      7.210345
# 2008-08-20      6.993563
# 2008-08-21      7.031264
# 2008-08-22      7.530804
# 2008-08-25      7.719310
# 2008-08-26      7.276321
# 2008-08-27      7.163218
# 2008-08-28      7.248046
# 2008-08-29      7.163218
# 2008-09-02      7.587357
# 2008-09-03      7.747586
# 2008-09-04      7.596782
# 2008-09-05      7.351724
# 2008-09-08      7.549655
# 2008-09-09      7.493103
# 2008-09-10      7.361149
# 2008-09-11      7.210345
# 2008-09-12      7.587357
# 2008-09-15      7.549655
# 2008-09-16      7.653333
# 2008-09-17      7.295172
# 2008-09-18      7.068965
# 2008-09-19      7.417701
# 2008-09-22      7.059540
# 2008-09-23      6.776782
#                  ...
# 2018-08-27    243.600006
# 2018-08-28    244.250000
# 2018-08-29    245.199997
# 2018-08-30    249.350006
# 2018-08-31    253.350006
# ...

# %%
print(stock[["Close","Open"]])
# Out:
#                  Close        Open
# Date
# 2008-08-12    7.320000    8.000000
# 2008-08-13    8.650000    7.830000
# 2008-08-14   10.090000    8.600000
# 2008-08-15    9.810000   10.100000
# 2008-08-18    8.340000    9.900000
# 2008-08-19    7.650000    8.050000
# 2008-08-20    7.420000    7.550000
# 2008-08-21    7.460000    7.000000
# 2008-08-22    7.990000    7.500000
# 2008-08-25    8.190000    8.530000
# 2008-08-26    7.720000    8.050000
# 2008-08-27    7.600000    7.510000
# 2008-08-28    7.690000    7.700000
# 2008-08-29    7.600000    7.380000
# 2008-09-02    8.050000    7.010000
# 2008-09-03    8.220000    9.030000
# 2008-09-04    8.060000    7.850000
# 2008-09-05    7.800000    8.100000
# 2008-09-08    8.010000    7.610000
# 2008-09-09    7.950000    7.860000
# 2008-09-10    7.810000    8.000000
# 2008-09-11    7.650000    7.810000
# 2008-09-12    8.050000    7.650000
# 2008-09-15    8.010000    8.150000
# 2008-09-16    8.120000    8.190000
# ...

# %%
print(stock.pct_change())
# Out:
#                 High       Low      Open     Close    Volume  Adj Close
# Date
# 2008-08-12       NaN       NaN       NaN       NaN       NaN        NaN
# 2008-08-13  0.126250  0.201538 -0.021250  0.181694  0.415929   0.181694
# 2008-08-14  0.129856  0.101152  0.098340  0.166474  0.850000   0.166474
# 2008-08-15  0.090373  0.139535  0.174419 -0.027750  0.030405  -0.027750
# 2008-08-18 -0.108108 -0.173469 -0.019802 -0.149847  0.222951  -0.149847
# 2008-08-19 -0.181818 -0.123457 -0.186869 -0.082734  1.726542  -0.082734
# 2008-08-20 -0.043210 -0.005634 -0.062112 -0.030065  2.356932  -0.030065
# 2008-08-21  0.161290 -0.011331 -0.072848  0.005391  0.978325   0.005391
# 2008-08-22 -0.080000  0.074499  0.071429  0.071046 -0.598164   0.071046
# 2008-08-25  0.073672  0.073333  0.137333  0.025031 -0.152542   0.025031
# 2008-08-26 -0.084364 -0.085714 -0.056272 -0.057387 -0.483043  -0.057387
# 2008-08-27 -0.023342 -0.023098 -0.067081 -0.015544  0.158957  -0.015544
# ...

# %%
df_stock = stock.pct_change()["Adj Close"]
print(df_stock)
# Out:
# Date
# 2008-08-12         NaN
# 2008-08-13    0.181694
# 2008-08-14    0.166474
# 2008-08-15   -0.027750
# 2008-08-18   -0.149847
# 2008-08-19   -0.082734
# 2008-08-20   -0.030065
# 2008-08-21    0.005391
# 2008-08-22    0.071046
# 2008-08-25    0.025031
# 2008-08-26   -0.057387
# 2008-08-27   -0.015544
# 2008-08-28    0.011842
# 2008-08-29   -0.011704
# 2008-09-02    0.059211
# 2008-09-03    0.021118
# 2008-09-04   -0.019465
# 2008-09-05   -0.032258
# 2008-09-08    0.026923
# 2008-09-09   -0.007491
# 2008-09-10   -0.017610
# 2008-09-11   -0.020487
# 2008-09-12    0.052288
# 2008-09-15   -0.004969
# 2008-09-16    0.013733
# 2008-09-17   -0.046798
# 2008-09-18   -0.031008
# 2008-09-19    0.049333
# 2008-09-22   -0.048285
# 2008-09-23   -0.040053
#                 ...
# 2018-08-27    0.014155
# 2018-08-28    0.002668
# 2018-08-29    0.003889
# 2018-08-30    0.016925
# 2018-08-31    0.016042
# 2018-09-04    0.016578
# 2018-09-05   -0.015531
# 2018-09-06   -0.018537
# ...

# %%
df_stock.dropna(inplace=True)

# %%
index = pdr.get_data_yahoo("SPY", startDate, endDate)
print(index)
# Out:
#                   High         Low        Open       Close       Volume  \
# Date
# 2008-01-02  146.990005  143.880005  146.529999  144.929993  204935600.0
# 2008-01-03  145.490005  144.070007  144.910004  144.860001  125133300.0
# 2008-01-04  143.440002  140.910004  143.339996  141.309998  232330900.0
# 2008-01-07  142.229996  140.100006  141.809998  141.190002  234991000.0
# 2008-01-08  142.899994  138.440002  142.080002  138.910004  326365700.0
# 2008-01-09  140.789993  137.699997  139.089996  140.369995  301824900.0
# 2008-01-10  142.800003  139.369995  139.679993  141.289993  335701200.0
# 2008-01-11  141.899994  139.000000  140.779999  140.149994  267076600.0
# 2008-01-14  141.860001  140.399994  141.160004  141.279999  170365500.0
# 2008-01-15  141.490005  137.899994  139.789993  138.169998  239940100.0
# 2008-01-16  139.119995  136.279999  137.360001  136.979996  378802600.0
# 2008-01-17  137.880005  132.929993  137.809998  133.429993  397892600.0
# ...

# %%
oil = pdr.fred.FredReader("DCOILWTICO", startDate, endDate).read()
print(oil)
# Out:
#             DCOILWTICO
# DATE
# 2008-01-01         NaN
# 2008-01-02       99.64
# 2008-01-03       99.17
# 2008-01-04       97.90
# 2008-01-07       95.08
# 2008-01-08       96.43
# 2008-01-09       95.64
# 2008-01-10       93.92
# 2008-01-11       92.74
# 2008-01-14       94.23
# 2008-01-15       91.87
# 2008-01-16       90.80
# 2008-01-17       90.11
# 2008-01-18       90.55
# 2008-01-21         NaN
# 2008-01-22       89.64
# 2008-01-23       87.65
# 2008-01-24       89.98
# 2008-01-25       90.37
# 2008-01-28       90.99
# 2008-01-29       91.66
# 2008-01-30       92.34
# 2008-01-31       91.67
# 2008-02-01       89.03
# 2008-02-04       90.07
# 2008-02-05       88.32
# 2008-02-06       87.16
# 2008-02-07       88.07
# 2008-02-08       91.77
# 2008-02-11       93.56
# ...                ...
# 2018-08-21       67.32
# 2018-08-22       67.85
# 2018-08-23       69.13
# 2018-08-24       69.71
# 2018-08-27       69.97
# 2018-08-28       68.54
# 2018-08-29       69.68
# ...

# %%
gold = pdr.fred.FredReader("GOLDAMGBD228NLBM", startDate, endDate).read()
print(gold)
# Out:
#             GOLDAMGBD228NLBM
# DATE
# 2008-01-01               NaN
# 2008-01-02            840.75
# 2008-01-03            865.35
# 2008-01-04            858.75
# 2008-01-07            857.50
# 2008-01-08            873.25
# 2008-01-09            887.85
# 2008-01-10            874.25
# 2008-01-11            893.75
# 2008-01-14            911.50
# 2008-01-15            904.75
# 2008-01-16            881.00
# 2008-01-17            881.50
# 2008-01-18            872.75
# 2008-01-21            874.25
# 2008-01-22            862.00
# 2008-01-23            887.80
# 2008-01-24            891.50
# 2008-01-25            921.25
# 2008-01-28            916.50
# 2008-01-29            927.50
# 2008-01-30            923.75
# 2008-01-31            923.75
# 2008-02-01            933.00
# 2008-02-04            899.50
# 2008-02-05            889.75
# 2008-02-06            892.00
# 2008-02-07            908.25
# 2008-02-08            914.00
# 2008-02-11            925.50
# ...                      ...
# ...

# %%
naturalGas = pdr.fred.FredReader("DHHNGSP", startDate, endDate).read()
print(naturalGas)
# Out:
#             DHHNGSP
# DATE
# 2008-01-01      NaN
# 2008-01-02     7.83
# 2008-01-03     7.84
# 2008-01-04     7.51
# 2008-01-07     7.61
# 2008-01-08     7.59
# 2008-01-09     7.89
# 2008-01-10     7.96
# 2008-01-11     8.13
# 2008-01-14     8.45
# 2008-01-15     8.43
# 2008-01-16     8.23
# 2008-01-17     8.10
# 2008-01-18     8.42
# 2008-01-21      NaN
# 2008-01-22     7.97
# 2008-01-23     7.84
# 2008-01-24     7.85
# 2008-01-25     7.80
# 2008-01-28     7.87
# 2008-01-29     8.10
# 2008-01-30     8.17
# 2008-01-31     8.10
# 2008-02-01     7.88
# 2008-02-04     7.56
# 2008-02-05     7.80
# 2008-02-06     7.94
# 2008-02-07     7.99
# 2008-02-08     8.06
# 2008-02-11     8.38
# ...             ...
# 2018-08-21     3.01
# 2018-08-22     3.02
# 2018-08-23     3.01
# 2018-08-24     2.99
# 2018-08-27     2.98
# 2018-08-28     2.98
# 2018-08-29     2.96
# 2018-08-30     2.96
# 2018-08-31     2.98
# 2018-09-03      NaN
# 2018-09-04     2.96
# 2018-09-05     3.00
# 2018-09-06     2.93
# ...

# %%
index = index["Adj Close"].pct_change()
oil = oil.pct_change()
gold = gold.pct_change()
naturalGas = naturalGas.pct_change()

# %%
import pandas as pd
df_indi = pd.concat([index, oil,gold,naturalGas], axis=1)
df_indi.dropna(inplace=True)
print(df_indi)
# Out:
#             Adj Close  DCOILWTICO  GOLDAMGBD228NLBM    DHHNGSP
# 2008-01-04  -0.024507   -0.012806         -0.007627 -33.957908
# 2008-01-07  -0.000849   -0.028805         -0.001456  -1.316346
# 2008-01-08  -0.016148    0.014199          0.018367  -1.197372
# 2008-01-09   0.010510   -0.008192          0.016719 -16.039526
# 2008-01-10   0.006554   -0.017984         -0.015318  -0.775539
# 2008-01-11  -0.008068   -0.012564          0.022305   1.407215
# 2008-01-14   0.008063    0.016066          0.019860   0.842993
# 2008-01-15  -0.022013   -0.025045         -0.007405  -1.060133
# 2008-01-16  -0.008612   -0.011647         -0.026250   9.023725
# 2008-01-17  -0.025916   -0.007599          0.000568  -0.334204
# 2008-01-18  -0.010267    0.004883         -0.009926  -3.501045
# 2008-01-22  -0.010147   -0.010050         -0.014012       -inf
# 2008-01-23   0.024021   -0.022200          0.029930  -0.694800
# 2008-01-24   0.008442    0.026583          0.004168  -1.078199
# ...

# %%
df_indi.to_csv("Variables.csv", encoding="UTF-8")

# %%
# libraries
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import matplotlib.dates as dates

# Data
#df_data=pd.DataFrame({y1: df_stock["Adj Close"]})

#x= range(1,2650)
#y= range(-1,5)

# multiple line plot
plt.plot(df_stock, marker='o', label = 'Stock', markerfacecolor='blue', markersize=12, color='skyblue', linewidth=4)
plt.plot(df_indi["Adj Close"], label = 'Index', marker='', color='olive', linewidth=2)
plt.plot(df_indi["DCOILWTICO"], label = 'Oil', marker='', color='green', linewidth=2)
plt.plot(df_indi["GOLDAMGBD228NLBM"], label = 'Gold', marker='', color='yellow', linewidth=2)
#plt.plot(df_indi["DHHNGSP"], label = 'Natual Gas', marker='', color='red', linewidth=1)
plt.legend()
plt.ylabel("Percent Change")
plt.xlabel("Time Range")
# Out:
# Text(0.5,0,'Time Range')

# %%
print(stock["Close"])
# Out:
# Date
# 2008-08-12      7.320000
# 2008-08-13      8.650000
# 2008-08-14     10.090000
# 2008-08-15      9.810000
# 2008-08-18      8.340000
# 2008-08-19      7.650000
# 2008-08-20      7.420000
# 2008-08-21      7.460000
# 2008-08-22      7.990000
# 2008-08-25      8.190000
# 2008-08-26      7.720000
# 2008-08-27      7.600000
# 2008-08-28      7.690000
# 2008-08-29      7.600000
# 2008-09-02      8.050000
# 2008-09-03      8.220000
# 2008-09-04      8.060000
# 2008-09-05      7.800000
# 2008-09-08      8.010000
# 2008-09-09      7.950000
# 2008-09-10      7.810000
# 2008-09-11      7.650000
# 2008-09-12      8.050000
# 2008-09-15      8.010000
# 2008-09-16      8.120000
# 2008-09-17      7.740000
# 2008-09-18      7.500000
# 2008-09-19      7.870000
# 2008-09-22      7.490000
# 2008-09-23      7.190000
#                  ...
# 2018-08-27    243.600006
# 2018-08-28    244.250000
# 2018-08-29    245.199997
# 2018-08-30    249.350006
# 2018-08-31    253.350006
# ...

# %%
plt.plot(stock["Close"], marker='o', label = 'Stock', markerfacecolor='blue', markersize=12, color='skyblue', linewidth=4)

# %%
startDate1 = datetime.datetime(2015,1,1)
stock_1 = pdr.get_data_yahoo("TREE", startDate1, endDate).reset_index()

# %%
#Data from Jan 2015 onwards
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.dates as dates
plt.plot(stock_1["Close"], marker='', label = 'Stock', markersize=10, color='blue', linewidth=4)

# %%
import plotly
plotly.tools.set_credentials_file(username='rkhuran', api_key='••••••••••')

# %%
import plotly

import plotly.plotly as py
import plotly.graph_objs as go
import cufflinks as cf


trace = go.Candlestick(x=stock_1.Date,
                       open=stock_1.Open,
                       high=stock_1.High,
                       low=stock_1.Low,
                       close=stock_1.Close)
data = [trace]
py.iplot(data, filename='simple_candlestick')
# Out:
# ---------------------------------------------------------------------------
# PlotlyRequestError                        Traceback (most recent call last)
# <ipython-input-14-eeee5b953693> in <module>()
#      12                        close=stock_1.Close)
#      13 data = [trace]
# ---> 14 py.iplot(data, filename='simple_candlestick')
#
# ~\Anaconda3\lib\plotly\plotly\plotly.py in iplot(figure_or_data, **plot_options)
#     140     if 'auto_open' not in plot_options:
#     141         plot_options['auto_open'] = False
# --> 142     url = plot(figure_or_data, **plot_options)
#     143
#     144     if isinstance(figure_or_data, dict):
#
# ~\Anaconda3\lib\plotly\plotly\plotly.py in plot(figure_or_data, validate, **plot_options)
#     237     data = fig.get('data', [])
#     238     plot_options['layout'] = fig.get('layout', {})
# --> 239     response = v1.clientresp(data, **plot_options)
#     240
#     241     # Check if the url needs a secret key
#
# ...

# %%
descibe.stock_1[]
# Out:
#   File "<ipython-input-15-cab8176c6e0c>", line 1
#     descibe.stock_1[]
#                     ^
# SyntaxError: invalid syntax

# %%
stock_1["Close"].describe()
# Out:
# count    949.000000
# mean     154.295311
# std       93.892426
# min       40.189999
# 25%       87.849998
# 50%      108.169998
# 75%      231.250000
# max      402.600006
# Name: Close, dtype: float64

# %%
y_hat = stock_1.copy()
plt.figure(figsize=(12,8))
plt.plot(stock_1.index, stock_1['Close'], color = 'red', label='Train')
plt.plot(stock_1.index,stock_1['Close'], label='Test')
plt.plot(y_hat.index,y_hat['Close'], label='Naive Forecast')
plt.legend(loc='best')
plt.show()


"""dd= np.asarray(train.Count)
y_hat = test.copy()
y_hat['naive'] = dd[len(dd)-1]
plt.figure(figsize=(12,8))
plt.plot(train.index, train['Count'], label='Train')
plt.plot(test.index,test['Count'], label='Test')
plt.plot(y_hat.index,y_hat['naive'], label='Naive Forecast')
plt.legend(loc='best')
plt.title("Naive Forecast")
plt.show()"""
# Out:
# 'dd= np.asarray(train.Count)\ny_hat = test.copy()\ny_hat[\'naive\'] = dd[len(dd)-1]\nplt.figure(figsize=(12,8))\nplt.plot(train.index, train[\'Count\'], label=\'Train\')\nplt.plot(test.index,test[\'Count\'], label=\'Test\')\nplt.plot(y_hat.index,y_hat[\'naive\'], label=\'Naive Forecast\')\nplt.legend(loc=\'best\')\nplt.title("Naive Forecast")\nplt.show()'

# %%
import datetime
startDate = datetime.datetime(2008,1,1)
endDate = datetime.datetime(2018,10,7)
import pandas_datareader as pdr
stock = pdr.get_data_yahoo("TREE", startDate, endDate)

# %%
stock.head()
# Out:
#              High   Low   Open  Close   Volume  Adj Close
# Date
# 2008-08-12   8.00  6.50   8.00   7.32  11300.0   6.899311
# 2008-08-13   9.01  7.81   7.83   8.65  16000.0   8.152873
# 2008-08-14  10.18  8.60   8.60  10.09  29600.0   9.510115
# 2008-08-15  11.10  9.80  10.10   9.81  30500.0   9.246207
# 2008-08-18   9.90  8.10   9.90   8.34  37300.0   7.860690

# %%
# libraries
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import matplotlib.dates as dates

condition = stock["Volume"] >=300000
stock[condition][:5]
# Out:
#             High   Low  Open  Close    Volume  Adj Close
# Date
# 2008-08-20  7.75  7.06  7.55   7.42  341400.0   6.993563
# 2008-08-21  9.00  6.98  7.00   7.46  675400.0   7.031264
# 2008-09-30  5.70  3.57  5.11   4.82  685800.0   4.542989
# 2008-10-08  3.17  1.96  3.13   2.03  734600.0   1.913333
# 2009-05-01  9.89  6.49  6.49   8.95  709400.0   8.435632

# %%
condition = stock["Volume"] >=300000
condition_2 = stock["Close"]>=200
stock[condition & condition_2][:5]
# Out:
#                   High         Low        Open       Close    Volume  \
# Date
# 2017-07-27  219.699997  197.550003  204.000000  217.149994  794000.0
# 2017-07-31  225.149994  215.399994  219.100006  220.600006  311100.0
# 2017-08-01  226.440002  221.649994  221.649994  224.250000  322300.0
# 2017-09-15  235.020004  227.399994  231.250000  227.750000  396600.0
# 2017-10-13  249.199997  233.759995  249.199997  238.399994  302300.0
#
#              Adj Close
# Date
# 2017-07-27  217.149994
# 2017-07-31  220.600006
# 2017-08-01  224.250000
# 2017-09-15  227.750000
# 2017-10-13  238.399994

# %%
stock.head()
# Out:
#              High   Low   Open  Close   Volume  Adj Close
# Date
# 2008-08-12   8.00  6.50   8.00   7.32  11300.0   6.899311
# 2008-08-13   9.01  7.81   7.83   8.65  16000.0   8.152873
# 2008-08-14  10.18  8.60   8.60  10.09  29600.0   9.510115
# 2008-08-15  11.10  9.80  10.10   9.81  30500.0   9.246207
# 2008-08-18   9.90  8.10   9.90   8.34  37300.0   7.860690

# %%
stock.plot(subplots = True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000002135ECEEBE0>,
# ...
#       dtype=object)

# %%
stock ["mavg"]= stock["Close"].shift(1)
stock.head()
# Out:
#              High   Low   Open  Close   Volume  Adj Close   mavg
# Date
# 2008-08-12   8.00  6.50   8.00   7.32  11300.0   6.899311    NaN
# 2008-08-13   9.01  7.81   7.83   8.65  16000.0   8.152873   7.32
# 2008-08-14  10.18  8.60   8.60  10.09  29600.0   9.510115   8.65
# 2008-08-15  11.10  9.80  10.10   9.81  30500.0   9.246207  10.09
# 2008-08-18   9.90  8.10   9.90   8.34  37300.0   7.860690   9.81

# %%
stock["return"]=stock["Close"].pct_change()

# %%
stock.head()
# Out:
#              High   Low   Open  Close   Volume  Adj Close   mavg    return
# Date
# 2008-08-12   8.00  6.50   8.00   7.32  11300.0   6.899311    NaN       NaN
# 2008-08-13   9.01  7.81   7.83   8.65  16000.0   8.152873   7.32  0.181694
# 2008-08-14  10.18  8.60   8.60  10.09  29600.0   9.510115   8.65  0.166474
# 2008-08-15  11.10  9.80  10.10   9.81  30500.0   9.246207  10.09 -0.027750
# 2008-08-18   9.90  8.10   9.90   8.34  37300.0   7.860690   9.81 -0.149847

# %%
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.datasets import load_iris
regr = LogisticRegression()
regr.fit(X,y)
regr.predict(X)

data = load_iris()
X =
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-24bf017e68cc> in <module>()
#       1 from sklearn.linear_model import LinearRegression, LogisticRegression
#       2 regr = LogisticRegression()
# ----> 3 regr.fit(X,y)
#       4 regr.predict(X)
#
# NameError: name 'X' is not defined

# %%
def foo():
    return
lambda x:x
lambda x:x**2
# Out:
# <function __main__.<lambda>(x)>
